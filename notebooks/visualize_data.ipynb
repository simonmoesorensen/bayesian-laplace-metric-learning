# %%
import sys
sys.path.append("../") # go to parent dir

# Change to whatever datamodule you want to visualize
from src.data_modules import CasiaDataModule

from pathlib import Path
import matplotlib.pyplot as plt

path = Path("/work3/s174420/datasets")

data = CasiaDataModule(
    data_dir=path,
    batch_size=64,
    num_workers=8,
    shuffle=True,
    pin_memory=True,
    sampler=None,
)

data.setup()
# Out:
# Training set size: 296648
# Validation set size: 98882
# Test set size: 98882
# OOD set size: 10000

# %%
for img, label in data.test_dataloader():
    plt.imshow(img[0].permute(1, 2, 0))
    break

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
for img, label in data.ood_dataloader():
    plt.imshow(img[0].permute(1, 2, 0))
    break

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
