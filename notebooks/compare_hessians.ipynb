# %%
import torch
import matplotlib.pyplot as plt

# %%
hessian_2 = torch.load("../hessian_2.pt")
hessian_32 = torch.load("../hessian_32.pt")

# %%
fig, ax = plt.subplots(figsize=(20, 4))
ax.plot(hessian_32.numpy(), label="32 latent dim")
ax.plot(hessian_2.numpy(), label="2 latent dim")
ax.set(xlabel="Layer", ylabel="Hessian")
ax.legend()
# ax.vlines(params, h.detach().cpu().numpy().min() + 1e-6, h.detach().cpu().numpy().max())
